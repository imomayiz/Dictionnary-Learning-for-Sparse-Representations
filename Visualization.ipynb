# %%
from matplotlib import pyplot as plt
from sklearn.datasets import load_digits
import numpy as np
from skimage import io
digits = load_digits()

D1 = np.loadtxt("dlm_files/dictionary_D1.dlm")
D2 = np.loadtxt("dlm_files/dictionary_D2.dlm")
D3 = np.loadtxt("dlm_files/dictionary_D3.dlm")
latent = np.loadtxt("dlm_files/Z3.dlm")

# %%
fig1 = plt.figure(1)

fig1.suptitle("Digits in the dataset", fontsize=18)
for i, image in enumerate(digits.images[:256]):
    ax = fig1.add_subplot(16, 16, i+1)
    ax.imshow(image, cmap='Greys_r')
    ax.set_axis_off()
plt.savefig('Images/digits_mnist.png')

# %%
fig2 = plt.figure(2)
fig2.suptitle("Obtained first dictionary", fontsize=18)
for i, atom in enumerate(D1[:10]):
    ax = fig2.add_subplot(5,2, i+1)
    ax.imshow(atom.reshape(15, 20), cmap='Greys_r')
    ax.set_axis_off()
plt.savefig('Images/first_dict_representation_mnist.png')

# %%
fig3 = plt.figure(3)
fig3.suptitle("Obtained second dictionary", fontsize=18)
for i, atom in enumerate(D2):
    ax = fig3.add_subplot(15,20, i+1)
    ax.imshow(atom.reshape(5, 3), cmap='Greys_r')
    ax.set_axis_off()
plt.savefig('Images/second_dict_representation_mnist.png')

# %%
fig3 = plt.figure(3)
fig3.suptitle("Obtained second dictionary", fontsize=18)
for i, atom in enumerate(D2[:10]):
    ax = fig3.add_subplot(4,4, i+1)
    ax.imshow(atom.reshape(5, 3), cmap='Greys_r')
    ax.set_axis_off()

# %%
fig3 = plt.figure(3)
fig3.suptitle("Obtained third dictionary", fontsize=18)
for i, atom in enumerate(D3):
    ax = fig3.add_subplot(5,3, i+1)
    ax.imshow(atom.reshape(5, 3), cmap='Greys_r')
    ax.set_axis_off()
plt.savefig('Images/third_dict_representation_mnist.png')

# %%
fig3 = plt.figure(3)
fig3.suptitle("Obtained Latent Representation", fontsize=18)
for i, atom in enumerate(latent):
    ax = fig3.add_subplot(4,4, i+1)
    ax.imshow(atom.reshape(8, 8), cmap='Greys_r')
    ax.set_axis_off()
plt.savefig('Images/latent_representation_mnist.png')
