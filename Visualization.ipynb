# %%
from matplotlib import pyplot as plt
from sklearn.datasets import load_digits
import numpy as np
from skimage import io
digits = load_digits()

reconstruction = np.loadtxt("reconstruction.dlm")

# %%
plt.figure(figsize=(4,4))
plt.imshow(digits.images[0].reshape(8, 8), cmap='Greys_r',vmin=0)
plt.title('Original Digit')
plt.savefig('original_digit.png')
plt.show()

# %%
plt.figure(figsize=(4,4))
plt.imshow(reconstruction[0].reshape(8, 8), cmap='Greys_r',vmin=0)
plt.title('Reconstructed Digit')
plt.savefig('reconstructed_digit.png')
plt.show()
